# %%
import sys
sys.path.insert(0, '/home/jovyan/')

from ocean_data_selector_demoing import OceanDataSelector
import pandas as pd
import numpy as np
import scipy.interpolate 
import metpy.interpolate
from datetime import datetime
import sqlalchemy

# %%
ods=OceanDataSelector()

# %% [markdown]
# ## Pulling WOD <span style='color:Blue'>***cast***</span> data from a map

# %%
ods.UI()
# Out:
# GridspecLayout(children=(Map(center=[0.0, 0.0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zo…

# %% [markdown]
# ### Get information about data

# %%
ods.data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cast_id                607 non-null    int64
#  1   timestamp              607 non-null    datetime64[ns]
#  2   geometry               607 non-null    geometry
#  3   year                   607 non-null    int64
#  4   dataset_id             0 non-null      object
#  5   changeset_id           0 non-null      object
#  6   subcategory            0 non-null      object
#  7   instrument_id          0 non-null      object
#  8   country                607 non-null    object
#  9   wod_cast_index         607 non-null    int64
#  10  wod_dataset_id         607 non-null    object
#  11  wod_cruise_identifier  607 non-null    object
#  12  platform               149 non-null    object
#  13  institute              182 non-null    object
# ...

# %% [markdown]
# ### View data as pandas dataframe

# %%
ods.data.head(5)
# Out:
#     cast_id               timestamp                    geometry  year  \
# 0  18895227 2018-09-21 04:07:30.000  POINT (-11.76130 47.06010)  2018
# 1  18999821 2018-10-16 09:53:27.238  POINT (-14.77230 48.96780)  2018
# 2  18680437 2018-01-25 15:50:38.040  POINT (-11.75900 42.04300)  2018
# 3  20301428 2018-06-12 10:13:08.038  POINT (-11.33606 50.90171)  2018
# 4  18882577 2018-08-26 05:29:02.761  POINT (-12.89500 44.65100)  2018
#
#   dataset_id changeset_id subcategory instrument_id        country  \
# 0       None         None        None          None        IRELAND
# 1       None         None        None          None        IRELAND
# 2       None         None        None          None  UNITED STATES
# 3       None         None        None          None        IRELAND
# 4       None         None        None          None        GERMANY
#
#    wod_cast_index                                     wod_dataset_id  \
# ...

# %% [markdown]
# ### View cast data on a map

# %%
ods.plot(ods.data)
# Out:
# <iframe src="about:blank" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.3.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#       margin: 0;
#       padding: 0;
#       overflow: hidden;
#     }
#
#     #deck-map-container {
#       width: 100%;
#       height: 100%;
#       background-color: black;
#     }
#
#     #map {
#       pointer-events: none;
#       height: 100%;
#       width: 100%;
#       position: absolute;
#       z-index: 1;
#     }
#
# ...

# %% [markdown]
# ## Pulling WOD <span style='color:Blue'>***measurement***</span> data from a map

# %%
ods.UI()
# Out:
# GridspecLayout(children=(Map(center=[0.0, 0.0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zo…

# %%
ods.data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cast_id                607 non-null    int64
#  1   timestamp              607 non-null    datetime64[ns]
#  2   geometry               607 non-null    geometry
#  3   year                   607 non-null    int64
#  4   dataset_id             0 non-null      object
#  5   changeset_id           0 non-null      object
#  6   subcategory            0 non-null      object
#  7   instrument_id          0 non-null      object
#  8   country                607 non-null    object
#  9   wod_cast_index         607 non-null    int64
#  10  wod_dataset_id         607 non-null    object
#  11  wod_cruise_identifier  607 non-null    object
#  12  platform               149 non-null    object
#  13  institute              182 non-null    object
# ...

# %%
ods.data.temperature[ods.data.temperature_flag==0].describe()
# Out:
# count    1437.000000
# mean       11.341834
# std         1.337851
# min         3.614000
# 25%        10.833000
# 50%        11.267000
# 75%        11.820000
# max        13.502000
# Name: temperature, dtype: float64

# %%
col='temperature'
ods.data[col].dropna().max(),ods.data[col].dropna().min()
# Out:
# (13.501999855041504, 3.614000082015991)

# %%
ods.plot(ods.data, col='temperature')
# Out:
# <iframe src="about:blank" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.3.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#       margin: 0;
#       padding: 0;
#       overflow: hidden;
#     }
#
#     #deck-map-container {
#       width: 100%;
#       height: 100%;
#       background-color: black;
#     }
#
#     #map {
#       pointer-events: none;
#       height: 100%;
#       width: 100%;
#       position: absolute;
#       z-index: 1;
#     }
#
# ...

# %%
ods.plot3d(ods.data,'temperature')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4962/3696216891.py in <module>
# ----> 1 ods.plot3d(ods.data,'temperature')
#
# ~/ocean_data_selector_demoing.py in plot3d(self, data, col, z_scale, terrain_scale)
#     259         #SURFACE_IMAGE="https://api.mapbox.com/styles/v1/oceandatafoundation/ckpy08q1h06kf17pfdx2yjybj/tiles/256/{z}/{x}/{y}@2x?access_token={%s}"%MAPBOX_API_KEY
#     260         SURFACE_IMAGE="https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}"
# --> 261         terrain_layer = pdk.Layer("TerrainLayer",
#     262                                   elevation_decoder=ELEVATION_DECODER,
#     263                                   texture=SURFACE_IMAGE,
#
# TypeError: __init__() missing 1 required positional argument: 'data'
