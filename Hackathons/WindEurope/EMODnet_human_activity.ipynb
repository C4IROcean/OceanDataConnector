# %% [markdown]
# # <span style='color:#FE774C'>EMODnet Human Activity </span> Example Notebook

# %% [markdown]
# #### We recommend duplicating this notebook if you want to make changes to the code or run additional analyses
# To do that simply right click on the file on the left panel and select "duplicate"

# %% [markdown]
# ### The first part of this notebook will show how to pull data, and run visualizations using functions
# ### The second part uses a gui based approach

# %%
import odp.geospatial as odp
import warnings
import cmocean

warnings.filterwarnings("ignore")
# Out:
# /srv/conda/envs/notebook/lib/python3.10/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.11.1-CAPI-1.17.1). Conversions between both will be slow.
#   warnings.warn(

# %%
db = odp.Database()
db_plt = odp.PlotTools()
gd = odp.GridData()

# %% [markdown]
# ### Part 1: Using Functions

# %% [markdown]
# #### The following shows the available datasets that can be used as dataframes. To see gridded datasets, run *gd.datasets_table* instead.
# #### Alternatively check out the data catalog in the [Ocean Data Explorer Catalog](https://app.oceandata.earth/catalog)

# %%
db.datasets
# Out:
#                                                                                  provider_acronym  \
# name
# World Ocean Database Casts                                                           [NOAA, NCEI]
# World Ocean Database Measurements                                                    [NOAA, NCEI]
# Marine Regions - IHO Sea Areas                                        [Flanders Marine Institute]
# Marine Regions - Intersect EEZ IHO Sea                                [Flanders Marine Institute]
# Marine Regions - World EEZ                                            [Flanders Marine Institute]
# Marine Regions - World Marine Heritage Sites                          [Flanders Marine Institute]
# Marine Regions - EEZ Land Union                                       [Flanders Marine Institute]
# Ocean Biodiversity Information System                                                      [OBIS]
# World Register of Marine Species                                                          [WoRMS]
# Norway Offshore wind - Proposals for study areas                                            [NVE]
# Lusedata                                          [Mattilsynet - Norwegian Food Safety Authority]
# Emodnet HA aquaculture - marine Finfish                                                 [EMODnet]
# Emodnet HA aquaculture - shellfish                                                      [EMODnet]
# Emodnet HA algae production                                                             [EMODnet]
# Emodnet HA offshore installations                                                       [EMODnet]
# Emodnet HA wells                                                                        [EMODnet]
# Emodnet HA pipelines                                                                    [EMODnet]
# Emodnet HA windfarms                                                                    [EMODnet]
# ProtectedSeas MPA Dataset                                                         [ProtectedSeas]
# OceanLab - Munkholmen buoy                                                               [SINTEF]
#
#                                                                                database_description  \
# name
# World Ocean Database Casts                        The World Ocean Database (WOD) is world's larg...
# World Ocean Database Measurements                 The World Ocean Database (WOD) is world's larg...
# Marine Regions - IHO Sea Areas                    Marine Regions tries to establish for the firs...
# Marine Regions - Intersect EEZ IHO Sea            Marine Regions tries to establish for the firs...
# Marine Regions - World EEZ                        Marine Regions tries to establish for the firs...
# Marine Regions - World Marine Heritage Sites      Marine Regions tries to establish for the firs...
# Marine Regions - EEZ Land Union                   Marine Regions tries to establish for the firs...
# Ocean Biodiversity Information System             Most comprehensive gateway to the world’s ocea...
# World Register of Marine Species                  Authoritative and comprehensive list of names ...
# Norway Offshore wind - Proposals for study areas  The data set shows a survey of the land use in...
# Lusedata                                          Data on lice counts of different lice types an...
# Emodnet HA aquaculture - marine Finfish           The database on marine finfish aquaculture in ...
# Emodnet HA aquaculture - shellfish                The database on shellfish aquaculture in the E...
# Emodnet HA algae production                       This dataset stems from the Joint Research Cen...
# Emodnet HA offshore installations                 The dataset on offshore installations for Oil ...
# Emodnet HA wells                                  The dataset on offshore wells for Oil and Gas ...
# Emodnet HA pipelines                              The dataset on offshore pipelines in the EU wa...
# Emodnet HA windfarms                              The database on offshore wind farms in the EU ...
# ProtectedSeas MPA Dataset                         Navigator catalogs boundary and regulation inf...
# OceanLab - Munkholmen buoy                        Weather and ocean data provided from the munkh...
#
#                                                                                   table_description  \
# name
# World Ocean Database Casts                        Dataset of the casts of the World Ocean Databa...
# World Ocean Database Measurements                 Dataset of measurements taken from all the cas...
# Marine Regions - IHO Sea Areas                                                                 None
# Marine Regions - Intersect EEZ IHO Sea            The intersect of the Exclusive Economic Zones ...
# Marine Regions - World EEZ                        Maritime Boundaries and Exclusive Economic Zon...
# Marine Regions - World Marine Heritage Sites                  World Marine Heritage Sites version 1
# Marine Regions - EEZ Land Union                     The union of world country boundaries and EEZ's
# Ocean Biodiversity Information System                                                          None
# World Register of Marine Species                                                               None
# Norway Offshore wind - Proposals for study areas  The data set shows a survey of the land use in...
# Lusedata                                          Data on lice counts of different lice types an...
# Emodnet HA aquaculture - marine Finfish           The database on marine finfish aquaculture in ...
# Emodnet HA aquaculture - shellfish                The database on shellfish aquaculture in the E...
# Emodnet HA algae production                       This dataset stems from the Joint Research Cen...
# Emodnet HA offshore installations                 The dataset on offshore installations for Oil ...
# Emodnet HA wells                                  The dataset on offshore wells for Oil and Gas ...
# Emodnet HA pipelines                              The dataset on offshore pipelines in the EU wa...
# Emodnet HA windfarms                              The database on offshore wind farms in the EU ...
# ProtectedSeas MPA Dataset                         Navigator catalogs boundary and regulation inf...
# OceanLab - Munkholmen buoy                        Weather and ocean data provided from the munkh...
#
#                                                                                            homepage  \
# name
# World Ocean Database Casts                        https://www.ncei.noaa.gov/products/world-ocean...
# World Ocean Database Measurements                 https://www.ncei.noaa.gov/products/world-ocean...
# Marine Regions - IHO Sea Areas                                       https://www.marineregions.org/
# Marine Regions - Intersect EEZ IHO Sea                               https://www.marineregions.org/
# Marine Regions - World EEZ                                           https://www.marineregions.org/
# Marine Regions - World Marine Heritage Sites                         https://www.marineregions.org/
# Marine Regions - EEZ Land Union                                      https://www.marineregions.org/
# Ocean Biodiversity Information System                                             https://obis.org/
# World Register of Marine Species                            https://www.marinespecies.org/index.php
# Norway Offshore wind - Proposals for study areas  https://kartkatalog.geonorge.no/metadata/havvi...
# Lusedata                                                                       https://lusedata.no/
# Emodnet HA aquaculture - marine Finfish           https://www.emodnet-humanactivities.eu/search-...
# Emodnet HA aquaculture - shellfish                https://www.emodnet-humanactivities.eu/search-...
# Emodnet HA algae production                       https://www.emodnet-humanactivities.eu/search-...
# Emodnet HA offshore installations                 https://www.emodnet-humanactivities.eu/search-...
# Emodnet HA wells                                  https://ows.emodnet-humanactivities.eu/geonetw...
# Emodnet HA pipelines                              https://www.emodnet-humanactivities.eu/search-...
# Emodnet HA windfarms                              https://www.emodnet-humanactivities.eu/search-...
# ProtectedSeas MPA Dataset                         https://protectedseas.net/mpa-mapping/#faq-sec...
# OceanLab - Munkholmen buoy                                          https://oceanlabobservatory.no/
#
#                                                                                            citation  \
# name
# World Ocean Database Casts                        Boyer, T.P., O.K. Baranova, C. Coleman, H.E. G...
# World Ocean Database Measurements                 Boyer, T.P., O.K. Baranova, C. Coleman, H.E. G...
# Marine Regions - IHO Sea Areas                    Flanders Marine Institute (2019). Maritime Bou...
# Marine Regions - Intersect EEZ IHO Sea            Flanders Marine Institute (2019). Maritime Bou...
# Marine Regions - World EEZ                        Flanders Marine Institute (2019). Maritime Bou...
# Marine Regions - World Marine Heritage Sites      Flanders Marine Institute (2019). Maritime Bou...
# Marine Regions - EEZ Land Union                   Flanders Marine Institute (2019). Maritime Bou...
# Ocean Biodiversity Information System             OBIS (YEAR) Ocean Biodiversity Information Sys...
# World Register of Marine Species                  WoRMS Editorial Board (2022). World Register o...
# Norway Offshore wind - Proposals for study areas                                               None
# Lusedata                                                                                       None
# Emodnet HA aquaculture - marine Finfish           EMODnet Human Activities, Aquaculture, Marine ...
# Emodnet HA aquaculture - shellfish                 EMODnet Human Activities, Aquaculture, Shellfish
# Emodnet HA algae production                               EMODnet Human Activities, Algae Productio
# Emodnet HA offshore installations                 EMODnet Human Activities, Oil and Gas, Offshor...
# Emodnet HA wells                                       EMODnet Human Activities, Oil and Gas, Wells
# Emodnet HA pipelines                                            EMODnet Human Activities, Pipelines
# Emodnet HA windfarms                                                  EMODnet_HA_WindFarms_20210217
# ProtectedSeas MPA Dataset                         Navigator Data Download, ProtectedSeas®, https...
# OceanLab - Munkholmen buoy                        Data provided by SINTEF OceanLab Observatoy, T...
#
#                                                                                             subject  \
# name
# World Ocean Database Casts                                                   global ocean variables
# World Ocean Database Measurements                                            global ocean variables
# Marine Regions - IHO Sea Areas                    marine georeferenced place names, locations, b...
# Marine Regions - Intersect EEZ IHO Sea            marine georeferenced place names, locations, b...
# Marine Regions - World EEZ                        marine georeferenced place names, locations, b...
# Marine Regions - World Marine Heritage Sites      marine georeferenced place names, locations, b...
# Marine Regions - EEZ Land Union                   marine georeferenced place names, locations, b...
# Ocean Biodiversity Information System                                     global ocean biodiversity
# World Register of Marine Species                               authoritative list of marine species
# Norway Offshore wind - Proposals for study areas             overview of wind farm assessment areas
# Lusedata                                                                                aquaculture
# Emodnet HA aquaculture - marine Finfish                                                 aquaculture
# Emodnet HA aquaculture - shellfish                                                      aquaculture
# Emodnet HA algae production                                                              production
# Emodnet HA offshore installations                                    offshore installations,oil,gas
# Emodnet HA wells                                                                      wells,oil,gas
# Emodnet HA pipelines                                                              pipelines,oil,gas
# Emodnet HA windfarms                                               energy,wind farms,human activity
# ProtectedSeas MPA Dataset                                                     MPA,protected regions
# OceanLab - Munkholmen buoy                                                  ocean variables,weather
#
#                                                                                                tags  \
# name
# World Ocean Database Casts                        [temperature, salinity, oxygen, nutrients, pre...
# World Ocean Database Measurements                 [temperature, salinity, oxygen, nutrients, pre...
# Marine Regions - IHO Sea Areas                                        [boundaries, iho sea, region]
# Marine Regions - Intersect EEZ IHO Sea                           [boundaries, iho sea, region, eez]
# Marine Regions - World EEZ                                         [boundaries, world, region, eez]
# Marine Regions - World Marine Heritage Sites      [boundaries,  world marine heritage sites, reg...
# Marine Regions - EEZ Land Union                                           [boundaries, region, eez]
# Ocean Biodiversity Information System                          [biodiversity, species, taxa, ocean]
# World Register of Marine Species                           [marine species, biodiversity, register]
# Norway Offshore wind - Proposals for study areas         [offshore wind power, study areas, energy]
# Lusedata                                                                [aquaculture, lice, salmon]
# Emodnet HA aquaculture - marine Finfish           [aquaculture, finfish, emodnet, human activiti...
# Emodnet HA aquaculture - shellfish                [aquaculture, shellfish, emodnet, human activi...
# Emodnet HA algae production                          [farming, economy, algae, production, economy]
# Emodnet HA offshore installations                 [economy, offshore, installation, assets, ener...
# Emodnet HA wells                                  [economy, offshore, wells, assets, energy, oil...
# Emodnet HA pipelines                              [economy, offshore, pipelines, assets, energy,...
# Emodnet HA windfarms                                           [energy, wind farms, human activity]
# ProtectedSeas MPA Dataset                         [marine protected areas, restrictions, managem...
# OceanLab - Munkholmen buoy                              [air temperature, wind, pressure, humidity]
#
#                                                                                               units
# name
# World Ocean Database Casts                        [celsius, dimensionless, micromole per kilogra...
# World Ocean Database Measurements                 [celsius, dimensionless, micromole per kilogra...
# Marine Regions - IHO Sea Areas                                                                 None
# Marine Regions - Intersect EEZ IHO Sea                                                         None
# Marine Regions - World EEZ                                                                     None
# Marine Regions - World Marine Heritage Sites                                                   None
# Marine Regions - EEZ Land Union                                                                None
# Ocean Biodiversity Information System                                                          None
# World Register of Marine Species                                                               None
# Norway Offshore wind - Proposals for study areas                                               None
# Lusedata                                                                                  [celsius]
# Emodnet HA aquaculture - marine Finfish                                                        None
# Emodnet HA aquaculture - shellfish                                                             None
# Emodnet HA algae production                                                                    None
# Emodnet HA offshore installations                                                              None
# Emodnet HA wells                                                                               None
# Emodnet HA pipelines                                                                           None
# Emodnet HA windfarms                                                                           None
# ProtectedSeas MPA Dataset                                                                      None
# OceanLab - Munkholmen buoy                        [celsius, hecto pascal, degrees, metres per se...

# %% [markdown]
# #### <span style='color:#3464eb'> Emodnet data available from catalog:<span>
#
# You can query data using the data catalog index name. Let's focus here on Emodnet dataset.

# %%
df_db = db.datasets
emodnet_list = [name for name in df_db.index if 'Emodnet' in name]
emodnet_list
# Out:
# ['Emodnet HA aquaculture - marine Finfish',
#  'Emodnet HA aquaculture - shellfish',
#  'Emodnet HA algae production',
#  'Emodnet HA offshore installations',
#  'Emodnet HA wells',
#  'Emodnet HA pipelines',
#  'Emodnet HA windfarms']

# %% [markdown]
# ## Pulling data - <span style='color:#FE774C'> Example with Emodnet HA - shellfish </span>

# %% [markdown]
# #### Insert the name of the table you are interested in into the query function
# This returns a [geopandas](https://geopandas.org/en/stable/docs.html) dataframe with a geometry column<br>
# There are many built-in functions you can use with these geopandas dataframes

# %%
shellfish_db = emodnet_list[0]

# %%
df = db.query(shellfish_db)
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2561 entries, 0 to 2560
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    2561 non-null   int64
#  1   COUNTRY     2561 non-null   object
#  2   OWNER_NAME  2561 non-null   object
#  3   PRODUCTION  2561 non-null   object
#  4   PURPOSE     2561 non-null   object
#  5   SPECIES_DE  2561 non-null   object
#  6   SITE_ID     2561 non-null   object
#  7   COAST_DIST  2561 non-null   float64
#  8   POSITION_C  2561 non-null   object
#  9   STATUS      2561 non-null   object
#  10  POINT_INFO  2561 non-null   object
#  11  COD         2561 non-null   object
#  12  HALIBUT     2561 non-null   object
#  13  LUMPFISH    2561 non-null   object
#  14  EEL         2561 non-null   object
#  15  SALMON      2561 non-null   object
#  16  SEABASS     2561 non-null   object
#  17  SEABREAM    2561 non-null   object
#  18  TROUT       2561 non-null   object
#  19  TUNA        2561 non-null   object
#  20  TURBOT      2561 non-null   object
#  21  SOLE        2561 non-null   object
#  22  OTHER_SPEC  2561 non-null   object
#  23  FARM_TYPE   2561 non-null   object
#  24  PRODUCTI_1  2561 non-null   object
#  25  geometry    2561 non-null   geometry
# dtypes: float64(1), geometry(1), int64(1), object(23)
# memory usage: 520.3+ KB

# %%
df.head()
# Out:
#    OBJECTID COUNTRY                     OWNER_NAME  \
# 0         1   Spain         ESTEROS MANGUITA, S.L.
# 1         2   Spain      ACUICULTURA ROQUETA, S.A.
# 2         3   Spain               BLENNIUS, S.C.A.
# 3         4   Spain  ESTEROS DE SANCTI PETRI, S.A.
# 4         5   Spain          MOLINERA DEL SUR S.A.
#
#                        PRODUCTION PURPOSE  \
# 0  Grow out for human consumption    n.a.
# 1                            n.a.    n.a.
# 2                            n.a.    n.a.
# 3                            n.a.    n.a.
# 4                      Broodstock    n.a.
#
#                                           SPECIES_DE  SITE_ID   COAST_DIST  \
# 0  Eel (Anguilla anguilla), European seabass (Dic...  ES_0001   585.283754
# 1  Eel (Anguilla anguilla), European seabass (Dic...  ES_0002    46.663899
# 2  Eel (Anguilla anguilla), European seabass (Dic...  ES_0003  2090.318606
# 3  Eel (Anguilla anguilla), European seabass (Dic...  ES_0004    80.395788
# 4  Common sole (Solea solea, S. vulgaris), Eel (A...  ES_0005   950.071873
#
#              POSITION_C STATUS  ... SEABASS SEABREAM TROUT TUNA TURBOT SOLE  \
# 0  Within the coastline   n.a.  ...     Yes      Yes    No   No     No  Yes
# 1  Within the coastline   n.a.  ...     Yes      Yes    No   No     No   No
# 2  Within the coastline   n.a.  ...     Yes      Yes    No   No     No   No
# 3                At sea   n.a.  ...     Yes      Yes    No   No     No   No
# 4  Within the coastline   n.a.  ...     Yes      Yes    No   No     No  Yes
#
#   OTHER_SPEC         FARM_TYPE       PRODUCTI_1                   geometry
# 0        Yes  Diversified farm  Saltwater ponds  POINT (-6.17444 36.44119)
# 1         No  Diversified farm             n.a.  POINT (-6.24601 36.46482)
# 2         No  Diversified farm             n.a.  POINT (-6.16763 36.48905)
# 3         No  Diversified farm  Saltwater ponds  POINT (-6.19739 36.38963)
# 4        Yes  Diversified farm  Saltwater ponds  POINT (-6.18603 36.42511)
#
# [5 rows x 26 columns]

# %% [markdown]
# #### <span style='color:#3464eb'>You can also access citation information, databsase description etc.

# %%
db.datasets.loc[emodnet_list[0]].database_description
# Out:
# 'The database on marine finfish aquaculture in the EU was created in 2017 by AND-International for the European Marine Observation and Data Network (EMODnet). The dataset provides information about the location of marine finfish farms in the EU and partner countries where data are available. There is an obligation for EU MS to inventory all authorized aquaculture sites under the Council Directive 2006/88/EC on animal health requirements. Despite this obligation, the availability of data varies among MS from no data available at all to a complete regularly updated dataset (e.g.in Ireland). As far as partner countries are concerned, data have been collected only in Norway and the UK (Scotland only) at this stage, where detailed data are provided online. Data provided here cover Cyprus, Danmark, Finland, Greece, Ireland, Malta, Norway, Spain and the UK (Scotland only). Data collection is still undergoing in other EU MS and neighbouring countries. Each point has the following attributes (where available): Country, Owner name, Status (Active, Expired, Inactive, Renewal, n.a.), Farm type (Flatfish, Diversified farm, Other specialised farm, Salmon, Salmonids, Seabass-seabream, Trout,Tuna, n.a.), Production method (Sea cages, Saltwater tanks/raceways, Saltwater ponds, Saltwater closed (recirculation), Quarantine, Other, n.a.), Production stage (Grow out for human consumption, Hatchery, Nursery, Brood stock, Reproduction, Restoration of wild stock, Put and take fisheries, Processing facility, Salughtering facility, Other, n.a.), Purpose (Commercial, Restocking, Other, n.a.), Products detailed (detailed product information names as presented in the source and translated to English), Point information (Polygon centroid, Original) depending on how the information is provided in the source (polygons or points), Site_ID. The farm type relies on a typology established by AND-International, based on available information on species grown. A relational table provides harmonised information about species grown using Eurostat nomenclature for the Species Group (Cods, hakes, haddocks; Flounders, halibuts, soles; Miscellaneous coastal fishes, Miscellaneous demersal fishes; Miscellaneous pelagic fishes; Salmons, trouts, smelts;Tunas, bonitos, billfishes), the species name (commercial and scientific) and the code. Compared with the previous version this new version has been not only updated but was also reviewed (dataset schema and attributes values), in order to add information on production methods, production stages and purposes and to provide a more useful typology based on species grown.'

# %%
for emodnet in emodnet_list:
    print(emodnet)
    df = db.query(emodnet)
    print(df.info())
# Out:
# Emodnet HA aquaculture - marine Finfish
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2561 entries, 0 to 2560
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    2561 non-null   int64
#  1   COUNTRY     2561 non-null   object
#  2   OWNER_NAME  2561 non-null   object
#  3   PRODUCTION  2561 non-null   object
#  4   PURPOSE     2561 non-null   object
#  5   SPECIES_DE  2561 non-null   object
#  6   SITE_ID     2561 non-null   object
#  7   COAST_DIST  2561 non-null   float64
#  8   POSITION_C  2561 non-null   object
#  9   STATUS      2561 non-null   object
#  10  POINT_INFO  2561 non-null   object
#  11  COD         2561 non-null   object
#  12  HALIBUT     2561 non-null   object
#  13  LUMPFISH    2561 non-null   object
#  14  EEL         2561 non-null   object
#  15  SALMON      2561 non-null   object
#  16  SEABASS     2561 non-null   object
#  17  SEABREAM    2561 non-null   object
#  18  TROUT       2561 non-null   object
#  19  TUNA        2561 non-null   object
#  20  TURBOT      2561 non-null   object
#  21  SOLE        2561 non-null   object
#  22  OTHER_SPEC  2561 non-null   object
#  23  FARM_TYPE   2561 non-null   object
#  24  PRODUCTI_1  2561 non-null   object
#  25  geometry    2561 non-null   geometry
# dtypes: float64(1), geometry(1), int64(1), object(23)
# memory usage: 520.3+ KB
# None
# Emodnet HA aquaculture - shellfish
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2169 entries, 0 to 2168
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SITE_ID     2169 non-null   object
#  1   COUNTRY     2169 non-null   object
#  2   OWNER_NAME  2169 non-null   object
#  3   AREA_NAME   2169 non-null   object
#  4   STATUS      2169 non-null   object
#  5   FARM_TYPE   2169 non-null   object
#  6   PRODUCTION  2169 non-null   object
#  7   PRODUCTI_1  2169 non-null   object
#  8   PURPOSE     2169 non-null   object
#  9   SPECIES_DE  2169 non-null   object
#  10  POINT_INFO  2169 non-null   object
#  11  POINT_DEFI  2169 non-null   object
#  12  COAST_DIST  2169 non-null   float64
#  13  POSITION_C  2169 non-null   object
#  14  geometry    2169 non-null   geometry
# dtypes: float64(1), geometry(1), object(13)
# memory usage: 254.3+ KB
# None
# Emodnet HA algae production
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID_Site     422 non-null    object
#  1   Owner_name  422 non-null    object
#  2   Country     422 non-null    object
#  3   Lat         422 non-null    float64
#  4   Long        422 non-null    float64
#  5   Pos_info    422 non-null    object
#  6   geometry    422 non-null    geometry
# dtypes: float64(2), geometry(1), object(4)
# memory usage: 23.2+ KB
# None
# Emodnet HA offshore installations
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2105 entries, 0 to 2104
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    2105 non-null   int64
#  1   ID          2098 non-null   object
#  2   Country     2105 non-null   object
#  3   Name        2105 non-null   object
#  4   Production  2105 non-null   int64
#  5   Location_b  1754 non-null   object
#  6   Operator    2037 non-null   object
#  7   Current_st  2105 non-null   object
#  8   Primary_pr  1672 non-null   object
#  9   Category    1755 non-null   object
#  10  Function    1861 non-null   object
#  11  Weight_sub  2105 non-null   float64
#  12  Weight_top  2105 non-null   float64
#  13  Water_dept  2105 non-null   float64
#  14  Coast_dist  2105 non-null   float64
#  15  Remarks     1283 non-null   object
#  16  geometry    2105 non-null   geometry
# dtypes: float64(4), geometry(1), int64(2), object(10)
# memory usage: 279.7+ KB
# None
# Emodnet HA wells
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STATUS      26457 non-null  object
#  1   COUNTRY     26457 non-null  object
#  2   CODE        26436 non-null  object
#  3   NAME        14403 non-null  object
#  4   YEAR        26457 non-null  int64
#  5   PURPOSE     26256 non-null  object
#  6   CONTENT     22873 non-null  object
#  7   OPERATOR    25038 non-null  object
#  8   DRILLING_C  10941 non-null  object
#  9   COAST_DIST  26457 non-null  float64
#  10  WATER_DEPT  26457 non-null  float64
#  11  geometry    26457 non-null  geometry
# dtypes: float64(2), geometry(1), int64(1), object(8)
# memory usage: 2.4+ MB
# None
# Emodnet HA pipelines
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 3933 entries, 0 to 3932
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          3400 non-null   object
#  1   NAME        2946 non-null   object
#  2   STATUS      3933 non-null   object
#  3   MEDIUM      3202 non-null   object
#  4   OPERATOR    3305 non-null   object
#  5   SIZE_IN     2627 non-null   object
#  6   LENGTH_M    3933 non-null   float64
#  7   YEAR        3933 non-null   int64
#  8   FROM_LOC    551 non-null    object
#  9   TO_LOC      503 non-null    object
#  10  COUNTRY_CO  3933 non-null   object
#  11  COUNTRY     3933 non-null   object
#  12  NOTES       2861 non-null   object
#  13  Shape_Leng  3933 non-null   float64
#  14  geometry    3933 non-null   geometry
# dtypes: float64(2), geometry(1), int64(1), object(11)
# memory usage: 461.0+ KB
# None
# Emodnet HA windfarms
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    186 non-null    int64
#  1   COUNTRY     186 non-null    object
#  2   NAME        186 non-null    object
#  3   N_TURBINES  186 non-null    float64
#  4   POWER_MW    186 non-null    float64
#  5   STATUS      186 non-null    object
#  6   YEAR        186 non-null    int64
#  7   COAST_DIST  186 non-null    float64
#  8   AREA_SQKM   186 non-null    float64
#  9   NOTES       0 non-null      object
#  10  Shape_Leng  186 non-null    float64
#  11  Shape_Area  186 non-null    float64
#  12  geometry    186 non-null    geometry
# dtypes: float64(6), geometry(1), int64(2), object(4)
# memory usage: 19.0+ KB
# None
