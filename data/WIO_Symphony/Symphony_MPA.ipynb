# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sqlalchemy import create_engine
from shapely import Point, wkt

import rasterio
import rioxarray
import json
from glob import glob

# %%
#Define path and one file example
PATH_WIO = "/Users/xavierpivan/HubOcean/wiosym/products/v2.1/output_geotiffs/"
PATH_SENSITIVITY = "/Users/xavierpivan/HubOcean/wiosym/"

sensitivity_path = PATH_SENSITIVITY+"Sensitivity Matrix 20220224.xlsx"

ecosystem_path = PATH_WIO+"eco/"
pressure_path = PATH_WIO+"pres/"

eco_files_list = glob(ecosystem_path+'*.tif')
pres_files_list = glob(pressure_path+'*.tif')

# %%
with open('/Users/xavierpivan/.secret.json', 'r') as file:
    conn_params = json.load(file)
conn_str = f"{conn_params['username']}:{conn_params['password']}@{conn_params['host']}/{conn_params['database']}"
engine = create_engine(conn_str)

# %%
# Format the connection string
xds = rioxarray.open_rasterio(eco_files_list[0])
lon = xds.x.values
lat = xds.y.values
#del xds

lonmin, lonmax = np.min(lon), np.max(lon)
latmin, latmax = np.min(lat), np.max(lat)

lon_grid, lat_grid = np.meshgrid(lon, lat)

print(f"Longitude ranges from {lonmin} to {lonmax}")
print(f"Latitude ranges from {latmin} to {latmax}")
# Out:
# Longitude ranges from 7.909201804826568 to 78.08112180482657
# Latitude ranges from -40.04344441182884 to 16.08055558817116

# %%
query = f'''
    select id,
    ST_AsText(geom) AS geom_text,
    ST_XMin(ST_Envelope(geom)) AS min_lon,
    ST_YMin(ST_Envelope(geom)) AS min_lat,
    ST_XMax(ST_Envelope(geom)) AS max_lon,
    ST_YMax(ST_Envelope(geom)) AS max_lat,
    ST_Area(geom) AS area, 
    ST_Perimeter(geom) AS perimeter, 
    ST_AsText(ST_Centroid(geom)) AS centroid_text, 
    "ORIG_NAME"
    FROM marine_protected_areas
    WHERE ST_Within(
        ST_SetSRID(ST_Centroid(geom), 4326),
        ST_MakeEnvelope({lonmin}, {latmin}, {lonmax}, {latmax}, 4326)
    );
'''

# %%
df = pd.read_sql_query(query, engine)
df.set_index('id', inplace=True)
df['geometry'] = df['geom_text'].apply(wkt.loads)
df.drop(columns='geom_text', inplace=True)
multi_polygon = df['geometry'].iloc[0]

# %%
min_lon, min_lat, max_lon, max_lat = ex[['min_lon', 'min_lat', 'max_lon', 'max_lat']].values

# %%
top_left_corner = xds.sel(x=min_lon, y=max_lat, method='nearest')
bottom_right_corner = xds.sel(x=max_lon, y=min_lat, method='nearest')

ind_lon_0 = np.where(lon==top_left_corner.x.values)[0][0]
ind_lat_0 = np.where(lat==top_left_corner.y.values)[0][0]
ind_lon_1 = np.where(lon==bottom_right_corner.x.values)[0][0]
ind_lat_1 = np.where(lat==bottom_right_corner.y.values)[0][0]

lon_grid, lat_grid = np.meshgrid(lon[ind_lon_0:ind_lon_1], lat[ind_lat_0:ind_lat_1]) 

point_list = np.array(list(zip(np.ravel(lon_grid), np.ravel(lat_grid))))

# %%
from shapely.geometry import Point
import geopandas as gpd

points = [Point(x,y) for x, y in point_list]
gdf = gpd.GeoDataFrame({'geometry': [multi_polygon]})
points_gdf = gpd.GeoDataFrame(geometry=points)
within = gpd.sjoin(points_gdf, gdf, op='within')
indices = within.index.to_list()
point_symphony = point_list[indices]
# Out:
# /Users/xavierpivan/HubOcean/VesselEmissions/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
# Out:
# 3 POINT (73.45440180482657 3.8945555881711584)
# 4 POINT (73.46358180482657 3.8945555881711584)
# 5 POINT (73.47276180482658 3.8945555881711584)
# 8 POINT (73.47276180482658 3.88555558817116)

# %%
x_list = [point for point in points if multi_polygon.contains(point)]

# %%
type(within)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
dx = lon[1]-lon[0]
dy = lat[1]-lat[0]

# %%
from shapely.wkt import loads
from shapely.geometry import MultiPolygon, Polygon, Point

# Convert string representations to Shapely Point objects
points = [loads(p) for p in poly['vertex']]

polygon = Polygon([(p.x, p.y) for p in points])
multi_polygon = MultiPolygon([polygon])

# %%
len(lon)
# Out:
# 7645

# %%
poly

# %%
for index, row in df.iterrows():
    row
# Out:
#        id    min_lon    min_lat    max_lon    max_lat       area  perimeter
# 0    1751  73.451318   3.880997  73.481495   3.899827   0.000306   0.077866  \
# 1    4814  29.295410 -31.910592  29.399243 -31.810610   0.003887   0.288456
# 2    4815  28.825605 -32.417694  29.061070 -32.187983   0.027762   0.661598
# 3    5142  18.250002 -34.407400  18.556883 -33.901249   0.091171   2.163697
# 4    5143  30.726969 -30.373500  31.033300 -30.116663   0.060086   1.007017
# 5    5144  29.552141 -31.695000  30.290003 -31.111555   0.128942   1.893814
# 6    5776  18.896083 -34.407500  18.937339 -34.356652   0.001859   0.174206
# 7    5777  20.365421 -34.583161  20.927538 -34.453056   0.026435   1.171965
# 8    5778  22.835442 -34.103386  22.999923 -34.046413   0.001813   0.350347
# 9    5779  18.763540 -34.103337  18.810249 -34.081238   0.000162   0.103935
# 10   5780  17.949350 -33.088433  17.964350 -33.078433   0.000118   0.074648
# 11   5781  17.996583 -33.194061  18.122103 -33.061943   0.006118   0.409486
# 12   5782  17.921017 -33.055100  17.931033 -33.046767   0.000069   0.057945
# 13   5783  17.964350 -33.046767  17.972683 -33.041783   0.000042   0.026634
# 14   5784  23.371667 -34.127217  23.432783 -34.081933   0.002615   0.208025
# 15   5785  25.453600 -34.054722  25.526183 -34.029312   0.001219   0.174280
# 16   5786  17.932623 -33.333433  18.160017 -33.118450   0.008042   0.657389
# 17   5787  30.281681 -30.977867  30.326447 -30.944317   0.000750   0.124940
# 18   5788  23.576017 -34.110000  24.194417 -33.983333   0.031263   1.346816
# 19   6429  27.639783 -33.233633  28.411517 -32.680530   0.023129   1.193209
# 20   8038  14.500000 -27.959444  15.683604 -24.486111   0.812100   7.621480
# 21   8040  67.902201 -10.794556  75.850801  -2.287502  51.609631  26.118314
# 22  12170  21.308016 -34.399380  21.516967 -34.292324   0.002716   0.520395
# 23  12171  19.229650 -34.577381  19.378200 -34.425110   0.009106   0.449883
# 24  12529  24.883000 -34.883300  25.283300 -34.666700   0.013330   0.949225
# 25  12539  17.416687 -32.966690  17.633949 -32.707740   0.056180   0.951762
# 26  12530  19.213333 -36.534000  20.218256 -35.588333   0.027249   1.645302
# 27  12531  15.600000 -31.000004  16.000000 -30.666667   0.090332   1.243367
# 28  12532  25.107586 -37.537368  25.833498 -36.400000   0.604126   3.208687
# 29  12533  32.400801 -28.522365  33.252300 -26.858220   0.992198   4.530645
# 30  12534  20.498833 -36.033409  20.966667 -35.000000   0.428819   3.001177
# 31  12535  20.500122 -34.955811  20.667114 -34.833313   0.020405   0.578248
# 32  12536  18.000000 -33.900000  18.400600 -33.750000   0.055151   1.155210
# 33  12537  14.161812 -30.167000  15.166667 -29.666667   0.172130   2.891705
# 34  12538  16.666664 -32.716667  16.816667 -32.583333   0.008889   0.447802
# 35  12540  21.666667 -37.724328  22.624000 -35.891000   0.737550   5.003962
# 36  12541  17.833333 -37.673537  19.333313 -36.333313   0.781098   5.233269
# 37  12542  16.500000 -29.600933  16.750400 -29.416667   0.045987   0.868001
# 38  12543  17.369830 -30.916700  17.602157 -30.498001   0.051186   1.121624
# 39  12544  30.308515 -30.977867  30.816700 -30.700000   0.113632   1.437229
# 40  12545  25.707341 -33.875000  26.529800 -33.620338   0.142287   2.004692
# 41  12546  31.300300 -29.616667  32.250000 -28.932813   0.383929   2.650524
# 42  12547  27.183300 -33.750000  28.766700 -32.713883   0.413550   3.771522
#
#                                 centroid_text
# 0    POINT(73.4678224716562 3.89205380542491)  \
# 1   POINT(29.3471218935452 -31.8608099950625)
# 2   POINT(28.9410922323297 -32.3014206221442)
# 3   POINT(18.3764684184988 -34.2038011629693)
# 4   POINT(30.9104352703796 -30.2494226440954)
# 5   POINT(29.9282874311571 -31.4196353001543)
# 6   POINT(18.9176194066879 -34.3848049273508)
# 7   POINT(20.6187989749497 -34.5039264336271)
# 8   POINT(22.9292482349497 -34.0820877149573)
# 9   POINT(18.7913341998886 -34.0932565970758)
# 10  POINT(17.9573690072737 -33.0833449262896)
# 11  POINT(18.0506983867922 -33.1222275704595)
# 12  POINT(17.9259632949821 -33.0506517407046)
# 13        POINT(17.9685165005 -33.0442749855)
# 14  POINT(23.4028173658472 -34.1057952491708)
# 15  POINT(25.4911576742786 -34.0424539297822)
# 16   POINT(18.0589567314562 -33.230105158516)
# 17  POINT(30.3062405880609 -30.9599964723014)
# 18  POINT(23.8857171104349 -34.0464492738262)
# 19  POINT(28.0822910245814 -32.9182130016027)
# 20  POINT(14.9586884026338 -26.3413555849984)
# 21  POINT(71.9533619177354 -6.57318815965403)
# 22  POINT(21.4075402217336 -34.3584070171836)
# 23  POINT(19.3103192229968 -34.4914434660556)
# 24           POINT(25.0164333333334 -34.7889)
# 25  POINT(17.5252392355315 -32.8373160687969)
# 26  POINT(19.7685012596161 -36.1020469704259)
# 27   POINT(15.8182628507649 -30.794311614816)
# 28  POINT(25.4723695551709 -37.0354266347112)
# 29  POINT(32.9292721122651 -27.8178769145872)
# 30  POINT(20.7498403644512 -35.5646835332533)
# 31  POINT(20.5834765787725 -34.8945116675313)
# 32  POINT(18.1936898783633 -33.8307417010972)
# 33   POINT(14.814185197843 -30.0066751169102)
# 34  POINT(16.7416657213544 -32.6500001041817)
# 35  POINT(22.2074362494356 -36.6316438073369)
# 36  POINT(18.2836193416255 -36.9052520937905)
# 37  POINT(16.6252057806165 -29.5085913720889)
# 38   POINT(17.4549336299759 -30.771649682465)
# 39  POINT(30.6082146581775 -30.8501723385446)
# 40  POINT(26.0978995915501 -33.7760299923237)
# 41  POINT(31.7438637519945 -29.2851261003672)
# 42  POINT(27.9303246688099 -33.2593764901089)
#
#                                             ORIG_NAME
# 0                                     Guraidhoo Kandu  \
# 1                       Hluleka Marine Protected Area
# 2                   Dwesa-Cwebe Marine Protected Area
# 3   Table Mountain National Park Marine Protected ...
# 4                  Aliwal Shoal Marine Protected Area
# 5                     Pondoland Marine Protected Area
# 6                   Betty's Bay Marine Protected Area
# 7                       De Hoop Marine Protected Area
# 8                      Goukamma Marine Protected Area
# 9                    Helderberg Marine Protected Area
# 10                Jutten Island Marine Protected Area
# 11             Langebaan Lagoon Marine Protected Area
# 12                Malgas Island Marine Protected Area
# 13                Marcus Island Marine Protected Area
# 14                      Robberg Marine Protected Area
# 15                 Sardinia Bay Marine Protected Area
# 16           Sixteen Mile Beach Marine Protected Area
# 17                    Trafalgar Marine Protected Area
# 18                  Tsitsikamma Marine Protected Area
# 19                     Amathole Marine Protected Area
# 20             Namibian Islands Marine Protected Area
# 21  British Indian Ocean Territory Marine Protecte...
# 22                     Stilbaai Marine Protected Area
# 23   Walker Bay Whale Sanctuary Marine Protected Area
# 24        Port Elizabeth Corals Marine Protected Area
# 25                  Cape Canyon Marine Protected Area
# 26           Browns Bank Corals Marine Protected Area
# 27                  Childs Bank Marine Protected Area
# 28                Agulhas Front Marine Protected Area
# 29                 iSimangaliso Marine Protected Area
# 30         Agulhas Bank Complex Marine Protected Area
# 31                 Agulhas Muds Marine Protected Area
# 32                Robben island Marine Protected Area
# 33            Orange Shelf Edge Marine Protected Area
# 34                Benguela Muds Marine Protected Area
# 35    Southwest Indian Seamount Marine Protected Area
# 36  Southeast Atlantic Seamount Marine Protected Area
# 37        Namaqua Fossil Forest Marine Protected Area
# 38        Namaqua National Park Marine Protected Area
# 39                 Protea Banks Marine Protected Area
# 40                Addo Elephant Marine Protected Area
# 41                     uThukela Marine Protected Area
# 42            Amathole Offshore Marine Protected Area
#
#                                              geometry
# 0   MULTIPOLYGON (((73.455031515 3.89982694700007,...
# 1   MULTIPOLYGON (((29.3222735050001 -31.810610202...
# 2   MULTIPOLYGON (((28.9369944580001 -32.187982653...
# 3   MULTIPOLYGON (((18.397447587 -33.9056472739999...
# 4   MULTIPOLYGON (((31.0333000000001 -30.116663, 3...
# 5   MULTIPOLYGON (((30.1773357440001 -31.111555101...
# 6   MULTIPOLYGON (((18.937326828 -34.356651719, 18...
# 7   MULTIPOLYGON (((20.68281746 -34.453056325, 20....
# 8   MULTIPOLYGON (((22.958082195 -34.083251945, 22...
# 9   MULTIPOLYGON (((18.810248691 -34.099699024, 18...
# 10  MULTIPOLYGON (((17.949350005 -33.07843299, 17....
# 11  MULTIPOLYGON (((17.9965830250001 -33.072049955...
# 12  MULTIPOLYGON (((17.921017002 -33.04676699, 17....
# 13  MULTIPOLYGON (((17.9643500020001 -33.041782981...
# 14  MULTIPOLYGON (((23.371667002 -34.0869104879999...
# 15  MULTIPOLYGON (((25.526183002 -34.038124189, 25...
# 16  MULTIPOLYGON (((17.9326233620001 -33.118449873...
# 17  MULTIPOLYGON (((30.3051568830001 -30.944316993...
# 18  MULTIPOLYGON (((23.794015883 -34.0096549959999...
# 19  MULTIPOLYGON (((27.6405067270001 -33.194241807...
# 20  MULTIPOLYGON (((14.9588176030001 -26.000113421...
# 21  MULTIPOLYGON (((72.45391655 -10.794555664, 70....
# 22  MULTIPOLYGON (((21.4250545300001 -34.377306976...
# 23  MULTIPOLYGON (((19.229649996 -34.429779991, 19...
# 24  MULTIPOLYGON (((24.883 -34.8167, 25.2833000000...
# 25  MULTIPOLYGON (((17.416687 -32.708, 17.63355800...
# 26  MULTIPOLYGON (((20.2182560000001 -36.533923, 2...
# 27  MULTIPOLYGON (((15.6 -30.666667, 16.0000000000...
# 28  MULTIPOLYGON (((25.46941 -37.5119625999999, 25...
# 29  MULTIPOLYGON (((33.2523 -26.9508769999999, 33....
# 30  MULTIPOLYGON (((20.7 -34.9999999999999, 20.966...
# 31  MULTIPOLYGON (((20.500122 -34.833313, 20.66668...
# 32  MULTIPOLYGON (((18.4006000000001 -33.773, 18.4...
# 33  MULTIPOLYGON (((14.835 -30.167, 14.16181200000...
# 34  MULTIPOLYGON (((16.666664 -32.583336, 16.73333...
# 35  MULTIPOLYGON (((22.0772480000001 -37.7243281, ...
# 36  MULTIPOLYGON (((18.3000000000001 -37.673537, 1...
# 37  MULTIPOLYGON (((16.5000000000001 -29.416667, 1...
# 38  MULTIPOLYGON (((17.3698302170001 -30.498001228...
# 39  MULTIPOLYGON (((30.308514824 -30.977866997, 30...
# 40  MULTIPOLYGON (((25.707341415 -33.6203384799999...
# 41  MULTIPOLYGON (((31.8685070000001 -28.932813, 3...
# 42  MULTIPOLYGON (((27.9180000000001 -33.484872999...
