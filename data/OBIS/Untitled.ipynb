# %% [markdown]
# # OBIS

# %%
import odp

# %%
db=odp.Database()

# %%
df_sample=db.query('OBIS Biodiversity',
        limit=3)
df_sample
# Out:
# /Users/kristianauthen/opt/anaconda3/envs/py38/lib/python3.8/site-packages/odp-0.0.1-py3.8.egg/odp/odp_sdk_experimental.py:129: UserWarning: Results reached row limit. Increase limit if needed
#   warnings.warn("Results reached row limit. Increase limit if needed")
#                                      id  decimalLongitude  decimalLatitude  \
# 0  eed71485-b04e-426b-9348-501dd1387f15       -122.038547        36.586382
# 1  dd009898-3a01-4c60-9e4e-669b4db766b7          9.500000         1.500000
# 2  28c8c905-4a7a-4a29-8a74-45f819c19ca1        137.600000        -5.600000
#
#                       geometry                                eventDate  \
# 0  POINT (-122.03855 36.58638)                      2020-02-10T14:52:07
# 1      POINT (9.50000 1.50000)  2014-06-17T16:59:14/2014-10-10T22:10:39
# 2   POINT (137.60000 -5.60000)                      2015-09-30T15:43:00
#
#   eventTime depth  date_year month  year  ... higherClassification  \
# ...

# %%
df=db.query('OBIS Biodiversity',
            filters=[ ''' "scientificName" = 'Scomber scombrus' '''])

# %%
df
