# %% [markdown]
# # <span style='color:#FE774C'>World Register of Marine Species</span> Example Notebook

# %% [markdown]
# #### We recommend duplicating this notebook if you want to make changes to the code or run additional analyses
# To do that simply right click on the file on the left panel and select "duplicate"

# %%
import odp.geospatial as odp

import warnings
warnings.filterwarnings("ignore")

# %%
db=odp.Database()
db_plt= odp.PlotTools()

# %% [markdown]
# #### The following shows the available datasets that can be used as dataframes. To see gridded datasets, run *gd.datasets_table* instead.
# #### Alternatively check out the data catalog in the [Ocean Data Explorer Catalog](https://app.oceandata.earth/catalog)

# %%
db.datasets
# Out:
#                                                                                  provider_acronym  \
# name
# World Ocean Database Casts                                                           [NOAA, NCEI]
# World Ocean Database Measurements                                                    [NOAA, NCEI]
# Marine Regions - IHO Sea Areas                                        [Flanders Marine Institute]
# Marine Regions - Intersect EEZ IHO Sea                                [Flanders Marine Institute]
# Marine Regions - World EEZ                                            [Flanders Marine Institute]
# Marine Regions - World Marine Heritage Sites                          [Flanders Marine Institute]
# Marine Regions - EEZ Land Union                                       [Flanders Marine Institute]
# Ocean Biodiversity Information System                                                      [OBIS]
# World Register of Marine Species                                                          [WoRMS]
# Norway Offshore wind - Proposals for study areas                                            [NVE]
# Lusedata                                          [Mattilsynet - Norwegian Food Safety Authority]
# Emodnet HA aquaculture - marine Finfish                                                 [EMODnet]
# Emodnet HA aquaculture - shellfish                                                      [EMODnet]
# Emodnet HA algae production                                                             [EMODnet]
# Emodnet HA offshore installations                                                       [EMODnet]
# Emodnet HA wells                                                                        [EMODnet]
# Emodnet HA pipelines                                                                    [EMODnet]
# Emodnet HA windfarms                                                                    [EMODnet]
#
#                                                                                database_description  \
# name
# World Ocean Database Casts                        The World Ocean Database (WOD) is world's larg...
# World Ocean Database Measurements                 The World Ocean Database (WOD) is world's larg...
# Marine Regions - IHO Sea Areas                    Marine Regions tries to establish for the firs...
# Marine Regions - Intersect EEZ IHO Sea            Marine Regions tries to establish for the firs...
# Marine Regions - World EEZ                        Marine Regions tries to establish for the firs...
# Marine Regions - World Marine Heritage Sites      Marine Regions tries to establish for the firs...
# Marine Regions - EEZ Land Union                   Marine Regions tries to establish for the firs...
# Ocean Biodiversity Information System             Most comprehensive gateway to the world’s ocea...
# World Register of Marine Species                  Authoritative and comprehensive list of names ...
# Norway Offshore wind - Proposals for study areas  The data set shows a survey of the land use in...
# Lusedata                                          Data on lice counts of different lice types an...
# Emodnet HA aquaculture - marine Finfish           The database on marine finfish aquaculture in ...
# Emodnet HA aquaculture - shellfish                The database on shellfish aquaculture in the E...
# Emodnet HA algae production                       This dataset stems from the Joint Research Cen...
# Emodnet HA offshore installations                 The dataset on offshore installations for Oil ...
# Emodnet HA wells                                  The dataset on offshore wells for Oil and Gas ...
# Emodnet HA pipelines                              The dataset on offshore pipelines in the EU wa...
# Emodnet HA windfarms                              The database on offshore wind farms in the EU ...
#
#                                                                                   table_description  \
# name
# World Ocean Database Casts                        Dataset of the casts of the World Ocean Databa...
# World Ocean Database Measurements                 Dataset of measurements taken from all the cas...
# Marine Regions - IHO Sea Areas                                                                 None
# Marine Regions - Intersect EEZ IHO Sea            The intersect of the Exclusive Economic Zones ...
# Marine Regions - World EEZ                        Maritime Boundaries and Exclusive Economic Zon...
# Marine Regions - World Marine Heritage Sites                  World Marine Heritage Sites version 1
# Marine Regions - EEZ Land Union                     The union of world country boundaries and EEZ's
# Ocean Biodiversity Information System                                                          None
# World Register of Marine Species                                                               None
# Norway Offshore wind - Proposals for study areas  The data set shows a survey of the land use in...
# Lusedata                                          Data on lice counts of different lice types an...
# Emodnet HA aquaculture - marine Finfish           The database on marine finfish aquaculture in ...
# Emodnet HA aquaculture - shellfish                The database on shellfish aquaculture in the E...
# Emodnet HA algae production                       This dataset stems from the Joint Research Cen...
# Emodnet HA offshore installations                 The dataset on offshore installations for Oil ...
# Emodnet HA wells                                  The dataset on offshore wells for Oil and Gas ...
# Emodnet HA pipelines                              The dataset on offshore pipelines in the EU wa...
# Emodnet HA windfarms                              The database on offshore wind farms in the EU ...
#
#                                                                                            homepage  \
# name
# World Ocean Database Casts                        https://www.ncei.noaa.gov/products/world-ocean...
# World Ocean Database Measurements                 https://www.ncei.noaa.gov/products/world-ocean...
# Marine Regions - IHO Sea Areas                                       https://www.marineregions.org/
# Marine Regions - Intersect EEZ IHO Sea                               https://www.marineregions.org/
# Marine Regions - World EEZ                                           https://www.marineregions.org/
# Marine Regions - World Marine Heritage Sites                         https://www.marineregions.org/
# Marine Regions - EEZ Land Union                                      https://www.marineregions.org/
# Ocean Biodiversity Information System                                             https://obis.org/
# World Register of Marine Species                            https://www.marinespecies.org/index.php
# Norway Offshore wind - Proposals for study areas  https://kartkatalog.geonorge.no/metadata/havvi...
# Lusedata                                                                       https://lusedata.no/
# Emodnet HA aquaculture - marine Finfish           https://www.emodnet-humanactivities.eu/search-...
# Emodnet HA aquaculture - shellfish                https://www.emodnet-humanactivities.eu/search-...
# Emodnet HA algae production                       https://www.emodnet-humanactivities.eu/search-...
# Emodnet HA offshore installations                 https://www.emodnet-humanactivities.eu/search-...
# Emodnet HA wells                                  https://ows.emodnet-humanactivities.eu/geonetw...
# Emodnet HA pipelines                              https://www.emodnet-humanactivities.eu/search-...
# Emodnet HA windfarms                              https://www.emodnet-humanactivities.eu/search-...
#
#                                                                                            citation  \
# name
# World Ocean Database Casts                        Boyer, T.P., O.K. Baranova, C. Coleman, H.E. G...
# World Ocean Database Measurements                 Boyer, T.P., O.K. Baranova, C. Coleman, H.E. G...
# Marine Regions - IHO Sea Areas                    Flanders Marine Institute (2019). Maritime Bou...
# Marine Regions - Intersect EEZ IHO Sea            Flanders Marine Institute (2019). Maritime Bou...
# Marine Regions - World EEZ                        Flanders Marine Institute (2019). Maritime Bou...
# Marine Regions - World Marine Heritage Sites      Flanders Marine Institute (2019). Maritime Bou...
# Marine Regions - EEZ Land Union                   Flanders Marine Institute (2019). Maritime Bou...
# Ocean Biodiversity Information System             OBIS (YEAR) Ocean Biodiversity Information Sys...
# World Register of Marine Species                  WoRMS Editorial Board (2022). World Register o...
# Norway Offshore wind - Proposals for study areas                                               None
# Lusedata                                                                                       None
# Emodnet HA aquaculture - marine Finfish           EMODnet Human Activities, Aquaculture, Marine ...
# Emodnet HA aquaculture - shellfish                 EMODnet Human Activities, Aquaculture, Shellfish
# Emodnet HA algae production                               EMODnet Human Activities, Algae Productio
# Emodnet HA offshore installations                 EMODnet Human Activities, Oil and Gas, Offshor...
# Emodnet HA wells                                       EMODnet Human Activities, Oil and Gas, Wells
# Emodnet HA pipelines                                            EMODnet Human Activities, Pipelines
# Emodnet HA windfarms                                                  EMODnet_HA_WindFarms_20210217
#
#                                                                                             subject  \
# name
# World Ocean Database Casts                                                   global ocean variables
# World Ocean Database Measurements                                            global ocean variables
# Marine Regions - IHO Sea Areas                    marine georeferenced place names, locations, b...
# Marine Regions - Intersect EEZ IHO Sea            marine georeferenced place names, locations, b...
# Marine Regions - World EEZ                        marine georeferenced place names, locations, b...
# Marine Regions - World Marine Heritage Sites      marine georeferenced place names, locations, b...
# Marine Regions - EEZ Land Union                   marine georeferenced place names, locations, b...
# Ocean Biodiversity Information System                                     global ocean biodiversity
# World Register of Marine Species                               authoritative list of marine species
# Norway Offshore wind - Proposals for study areas             overview of wind farm assessment areas
# Lusedata                                                                                aquaculture
# Emodnet HA aquaculture - marine Finfish                                                 aquaculture
# Emodnet HA aquaculture - shellfish                                                      aquaculture
# Emodnet HA algae production                                                              production
# Emodnet HA offshore installations                                    offshore installations,oil,gas
# Emodnet HA wells                                                                      wells,oil,gas
# Emodnet HA pipelines                                                              pipelines,oil,gas
# Emodnet HA windfarms                                               energy,wind farms,human activity
#
#                                                                                                tags  \
# name
# World Ocean Database Casts                        [temperature, salinity, oxygen, nutrients, pre...
# World Ocean Database Measurements                 [temperature, salinity, oxygen, nutrients, pre...
# Marine Regions - IHO Sea Areas                                        [boundaries, iho sea, region]
# Marine Regions - Intersect EEZ IHO Sea                           [boundaries, iho sea, region, eez]
# Marine Regions - World EEZ                                         [boundaries, world, region, eez]
# Marine Regions - World Marine Heritage Sites      [boundaries,  world marine heritage sites, reg...
# Marine Regions - EEZ Land Union                                           [boundaries, region, eez]
# Ocean Biodiversity Information System                          [biodiversity, species, taxa, ocean]
# World Register of Marine Species                           [marine species, biodiversity, register]
# Norway Offshore wind - Proposals for study areas         [offshore wind power, study areas, energy]
# Lusedata                                                                [aquaculture, lice, salmon]
# Emodnet HA aquaculture - marine Finfish           [aquaculture, finfish, emodnet, human activiti...
# Emodnet HA aquaculture - shellfish                [aquaculture, shellfish, emodnet, human activi...
# Emodnet HA algae production                          [farming, economy, algae, production, economy]
# Emodnet HA offshore installations                 [economy, offshore, installation, assets, ener...
# Emodnet HA wells                                  [economy, offshore, wells, assets, energy, oil...
# Emodnet HA pipelines                              [economy, offshore, pipelines, assets, energy,...
# Emodnet HA windfarms                                           [energy, wind farms, human activity]
#
#                                                                                               units
# name
# World Ocean Database Casts                        temperature                                   ...
# World Ocean Database Measurements                 temperature                                   ...
# Marine Regions - IHO Sea Areas                                                                 None
# Marine Regions - Intersect EEZ IHO Sea                                                         None
# Marine Regions - World EEZ                                                                     None
# Marine Regions - World Marine Heritage Sites                                                   None
# Marine Regions - EEZ Land Union                                                                None
# Ocean Biodiversity Information System                                                          None
# World Register of Marine Species                                                               None
# Norway Offshore wind - Proposals for study areas                                               None
# Lusedata                                                       temperature    celsius
# dtype: object
# Emodnet HA aquaculture - marine Finfish                                                        None
# Emodnet HA aquaculture - shellfish                                                             None
# Emodnet HA algae production                                                                    None
# Emodnet HA offshore installations                                                              None
# Emodnet HA wells                                                                               None
# Emodnet HA pipelines                                                                           None
# Emodnet HA windfarms                                                                           None

# %% [markdown]
# ## Pulling data - <span style='color:#FE774C'> **WoRMS** </span>

# %% [markdown]
# #### Insert the name of the table you are interested in into the query function, and let's limit to 10 just to see what it looks like

# %%
cols_of_interest = ['aphia_id', 'scientific_name', 'rank', 'kingdom', 'phylum', 'class', 'order', 'genus', 'is_extinct']

df=db.query('World Register of Marine Species', 
            data_columns=cols_of_interest,
            limit=100)
df.head(3)
# Out:
#    aphia_id  scientific_name      rank   kingdom    phylum           class  \
# 0        59  Leptochitonidae    Family  Animalia  Mollusca  Polyplacophora
# 1        63  Ischnochitonina  Suborder  Animalia  Mollusca  Polyplacophora
# 2        64       Chitonidae    Family  Animalia  Mollusca  Polyplacophora
#
#             order genus  is_extinct
# 0  Lepidopleurida             False
# 1       Chitonida             False
# 2       Chitonida             False

# %% [markdown]
# ### Add <span style='color:#9D59F4'> **filters** </span> to the data pull

# %% [markdown]
# #### In this case we are intersted in the WoRMS data with the phylum name 'Mollusca'
# #### Using the filter function, you can create filters for whichever column of the dataset you are interested in.

# %% [markdown]
# Let's define the filters:
# We want Molluscs that are extinct

# %%
filter1 = db.filter_data('phylum', '=', 'Mollusca')
filter2 = db.filter_data("is_extinct", "=", "False")

# %% [markdown]
# And now let's pass into our query function

# %%
df=db.query('World Register of Marine Species',
            filters=[filter1, filter2],
            limit=10, 
            data_columns=cols_of_interest)

# %%
df.head(3)
# Out:
#    aphia_id  scientific_name      rank   kingdom    phylum           class  \
# 0        59  Leptochitonidae    Family  Animalia  Mollusca  Polyplacophora
# 1        63  Ischnochitonina  Suborder  Animalia  Mollusca  Polyplacophora
# 2        64       Chitonidae    Family  Animalia  Mollusca  Polyplacophora
#
#             order genus  is_extinct
# 0  Lepidopleurida             False
# 1       Chitonida             False
# 2       Chitonida             False

# %% [markdown]
# ### Use <span style='color:#FE774C'> **WoRMS** </span> output to query <span style='color:#FE774C'> **OBIS** </span>

# %% [markdown]
# Let's pick which columns we are interested in for OBIS (see OBIS Notebook)

# %%
cols_of_interest = ['id', 'aphiaID','geometry','timestamp', 'depth','date_year','month', 'kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species', 'scientificName']

# %%
filter1 = db.filter_data('aphiaID', '=', 59)

# %%
df_aphia=db.query('Ocean Biodiversity Information System', filters=[filter1], limit=10, data_columns=cols_of_interest)

# %%
df_aphia.head()
# Out:
#                                      id  aphiaID                     geometry  \
# 0  0736505d-35d4-4734-bb69-5de72d2f8b35       59  POINT (121.96930 -34.03828)
# 1  07d4d05d-a5a8-419c-b95a-e326bae973ed       59  POINT (121.94624 -33.89257)
# 2  2792705f-0d46-4985-ae5c-b71c7f88788f       59  POINT (121.99700 -33.97755)
# 3  b8ac059e-5e88-4123-910c-3964cb0266bf       59  POINT (122.00010 -33.97173)
# 4  5e6b9ef0-d844-45ed-9e6b-f4448f347dba       59  POINT (146.20472 -44.19383)
#
#    timestamp   depth  date_year month   kingdom    phylum           class  \
# 0 2002-11-13    26.0       2002  None  Animalia  Mollusca  Polyplacophora
# 1 2002-11-05    38.0       2002  None  Animalia  Mollusca  Polyplacophora
# 2 2002-06-12    29.0       2002  None  Animalia  Mollusca  Polyplacophora
# 3 2002-06-12    30.0       2002  None  Animalia  Mollusca  Polyplacophora
# 4 2007-04-06  1140.0       2007  None  Animalia  Mollusca  Polyplacophora
#
#             order           family genus species   scientificName
# 0  Lepidopleurida  Leptochitonidae  None    None  Leptochitonidae
# 1  Lepidopleurida  Leptochitonidae  None    None  Leptochitonidae
# 2  Lepidopleurida  Leptochitonidae  None    None  Leptochitonidae
# 3  Lepidopleurida  Leptochitonidae  None    None  Leptochitonidae
# 4  Lepidopleurida  Leptochitonidae  None    None  Leptochitonidae
