# %% [markdown]
# # <span style='color:#FE774C'>World Register of Marine Species</span> Example Notebook

# %%
import odp.geospatial as odp

import warnings
warnings.filterwarnings("ignore")

# %%
db=odp.Database()
db_plt= odp.PlotTools()

# %%
db.datasets
# Out:
#                                                  schema  \
# name
# OBIS Biodiversity                              raw_obis
# World Registry of Marine Species              raw_worms
# InterRidge hydrothermal vents            raw_interridge
# OceanLab                                  raw_oceanlabs
# vessel_emissions_2020_h3           vessel_emissions_map
# vessel_emissions_2020_h4           vessel_emissions_map
# vessel_emissions_2020_h5           vessel_emissions_map
# lusedata                                raw_ops_seafood
# World Seas IHO                        raw_marineregions
# Intersect EEZ IHO                     raw_marineregions
# World EEZ                             raw_marineregions
# World Marine Heritage Sites           raw_marineregions
# EEZ Land Union                        raw_marineregions
# World Ocean Database Measurements               raw_wod
# World Ocean Database Casts                      raw_wod
#
#                                                                table  \
# name
# OBIS Biodiversity                                        occurrences
# World Registry of Marine Species                                taxa
# InterRidge hydrothermal vents                                  vents
# OceanLab                                              trondheim_buoy
# vessel_emissions_2020_h3           emissions_map_2020_h3_month_class
# vessel_emissions_2020_h4           emissions_map_2020_h4_month_class
# vessel_emissions_2020_h5           emissions_map_2020_h5_month_class
# lusedata                                     joined_salmon_lice_data
# World Seas IHO                                     world_seas_iho_v3
# Intersect EEZ IHO                          intersect_eez_iho_v4_2020
# World EEZ                                     world_eez_v11_20191118
# World Marine Heritage Sites                 worldmarineheritagesites
# EEZ Land Union                              eez_land_union_v3_202003
# World Ocean Database Measurements                       observations
# World Ocean Database Casts                                     casts
#
#                                                                               labels
# name
# OBIS Biodiversity                        [biology, ecosystem, occurrence, organisms]
# World Registry of Marine Species                     [biology, organisms, ecosystem]
# InterRidge hydrothermal vents                                       [geology, vents]
# OceanLab                           [physics, wind, atmosphere, pressure, temperat...
# vessel_emissions_2020_h3           [human dimensions, estimated, emissions, human...
# vessel_emissions_2020_h4           [human dimensions, estimated, emissions, human...
# vessel_emissions_2020_h5           [human dimensions, estimated, emissions, human...
# lusedata                                                   [aquaculture, fish farms]
# World Seas IHO                                                   [marine boundaries]
# Intersect EEZ IHO                                                [marine boundaries]
# World EEZ                                                        [marine boundaries]
# World Marine Heritage Sites                                      [marine boundaries]
# EEZ Land Union                                                   [marine boundaries]
# World Ocean Database Measurements  [physics, phosphate, silicate, temperature, pr...
# World Ocean Database Casts                                          [physics, ocean]

# %% [markdown]
# ## Pulling data - <span style='color:#FE774C'> **WoRMS** </span>

# %% [markdown]
# #### Insert the name of the table you are interested in into the query function, and let's limit to 10 just to see what it looks like

# %%
cols_of_interest = ['aphia_id', 'scientific_name', 'rank', 'kingdom', 'phylum', 'class', 'order', 'genus', 'is_extinct']

df=db.query('World Registry of Marine Species', data_columns=cols_of_interest,
            limit=100)
df.head(3)
# Out:
#    aphia_id  scientific_name      rank   kingdom    phylum           class  \
# 0        59  Leptochitonidae    Family  Animalia  Mollusca  Polyplacophora
# 1        63  Ischnochitonina  Suborder  Animalia  Mollusca  Polyplacophora
# 2        64       Chitonidae    Family  Animalia  Mollusca  Polyplacophora
#
#             order genus  is_extinct
# 0  Lepidopleurida             False
# 1       Chitonida             False
# 2       Chitonida             False

# %% [markdown]
# ### Add <span style='color:#9D59F4'> **filters** </span> to the data pull

# %% [markdown]
# #### In this case we are intersted in the WoRMS data with the phylum name 'Mollusca'
# #### Using the filter function, you can create filters for whichever column of the dataset you are interested in.

# %% [markdown]
# Let's define the filters:
# We want Molluscs that are extinct

# %%
filter1 = db.filter_data('phylum', '=', 'Mollusca')
filter2 = db.filter_data("is_extinct", "=", "False")

# %% [markdown]
# And now let's pass into our query function

# %%
df=db.query('World Registry of Marine Species',
            filters=[filter1, filter2], limit=10, data_columns=cols_of_interest)

# %%
df.head(3)
# Out:
#    aphia_id  scientific_name      rank   kingdom    phylum           class  \
# 0        59  Leptochitonidae    Family  Animalia  Mollusca  Polyplacophora
# 1        63  Ischnochitonina  Suborder  Animalia  Mollusca  Polyplacophora
# 2        64       Chitonidae    Family  Animalia  Mollusca  Polyplacophora
#
#             order genus  is_extinct
# 0  Lepidopleurida             False
# 1       Chitonida             False
# 2       Chitonida             False

# %% [markdown]
# ### Use <span style='color:#FE774C'> **WoRMS** </span> output to query <span style='color:#FE774C'> **OBIS** </span>

# %% [markdown]
# Let's pick which columns we are interested in for OBIS (see OBIS Notebook)

# %%
cols_of_interest = ['id', 'aphiaID','geometry','timestamp', 'depth','date_year','month', 'kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species', 'scientificName']

# %%
filter1 = db.filter_data('aphiaID', '=', 59)

# %%
df_aphia=db.query('OBIS Biodiversity', filters=[filter1], limit=10, data_columns=cols_of_interest)

# %%
df_aphia.head()
# Out:
#                                      id  aphiaID                     geometry  \
# 0  0736505d-35d4-4734-bb69-5de72d2f8b35       59  POINT (121.96930 -34.03828)
# 1  07d4d05d-a5a8-419c-b95a-e326bae973ed       59  POINT (121.94624 -33.89257)
# 2  2792705f-0d46-4985-ae5c-b71c7f88788f       59  POINT (121.99700 -33.97755)
# 3  b8ac059e-5e88-4123-910c-3964cb0266bf       59  POINT (122.00010 -33.97173)
# 4  5e6b9ef0-d844-45ed-9e6b-f4448f347dba       59  POINT (146.20472 -44.19383)
#
#    timestamp   depth  date_year month   kingdom    phylum           class  \
# 0 2002-11-13    26.0       2002  None  Animalia  Mollusca  Polyplacophora
# 1 2002-11-05    38.0       2002  None  Animalia  Mollusca  Polyplacophora
# 2 2002-06-12    29.0       2002  None  Animalia  Mollusca  Polyplacophora
# 3 2002-06-12    30.0       2002  None  Animalia  Mollusca  Polyplacophora
# 4 2007-04-06  1140.0       2007  None  Animalia  Mollusca  Polyplacophora
#
#             order           family genus species   scientificName
# 0  Lepidopleurida  Leptochitonidae  None    None  Leptochitonidae
# 1  Lepidopleurida  Leptochitonidae  None    None  Leptochitonidae
# 2  Lepidopleurida  Leptochitonidae  None    None  Leptochitonidae
# 3  Lepidopleurida  Leptochitonidae  None    None  Leptochitonidae
# 4  Lepidopleurida  Leptochitonidae  None    None  Leptochitonidae
